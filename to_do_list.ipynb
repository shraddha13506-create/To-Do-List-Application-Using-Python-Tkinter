# %%
import tkinter as tk
window=tk.Tk()
window.title("my 1st window")
window.geometry("400x300")
window.mainloop()

# %% [markdown]
# # import tkinter as tk:
# * imports the Tkinter library - Python, I want to use GUI components.
#
# # window=tk.Tk():
# * root window.Imagine you're building a house.The house itself is the window.Everything else (buttons, labels, textboxes) goes inside this house.Without this line, there is nowhere to place widgets.
#
# # window.title("My first window")
# * Changes Untitled to -> my 1st window
#
# # window.geometry("400x300")
# * Makes the window
# 400 pixels wide
# 300 pixels tall
#
# # window.mainloop()
# * Without it
#
# Create window
# ↓
# Program ends
# ↓
# Window disappears
#
# * With it
#
# Create window
# ↓
# Wait for user
# ↓
# Click button?
# ↓
# Type something?
# ↓
# Close window?
# ↓
# Keep waiting...
#
# It keeps the application alive until you close it.

# %%
def add_task():
    task = task_entry.get()
    task_list.insert(tk.END, task)
    task_entry.delete(0, tk.END)
    task_list.insert(
        tk.END,
        f"{task_number}. {task}"
    )
    task_entry.delete(0, tk.END)

import tkinter as tk

window = tk.Tk()
window.configure(bg="peach puff")

window.title("To-Do List")
window.geometry("400x600")

label = tk.Label(window, text="My To-Do List", bg="#FFDAB9")

label.pack()

title = tk.Label(window,
                 text="Welcome to To-Do List program", bg="#FFB07C",
                 font=("Arial",18))
title.pack(pady=10)

task_entry = tk.Entry(window, width=30, font=("Arial", 14))
task_entry.pack(pady=5)

button = tk.Button(window, text="Add Task", command=add_task, bg="#F08080")
button.pack(pady=10)

task_list = tk.Listbox(window, width=40, height=25)
task_list.pack()

selected = task_list.curselection()
task_list.delete(selected)

tasks=task_list.get(0, tk.END)
task_list.delete(0, tk.END)

for i, task in enumerate(tasks, start=1):
    task_list.insert(f"{i}. {task.split(". ",1)[1]}")

window.mainloop()

# %% [markdown]
# # title=tk.Lable(winow, text="My To-Do List"):
# * creates a piece of text.
#
# # title.pack:
# * This tells Tkinter: "Actually put the label inside the window."Without pack(), the label exists in memory but isn't displayed.
#
# # pady:
# means Padding on Y-axis
# Think of it as empty space.
#
# Without pady:
# TITLE
# Textbox
#
# With pady:
# TITLE
#
# Textbox
#
# # tk.Entry:
# * creates an type entry
#
# # width=30:
# * It is not pixels.It means roughly 30 characters
# For example:
# Study for AI Exam tomorrow - fits nicely.
#
# # insert() -- var.insert(tk.END, task):
# * Insert the task at the end of the list
#
# # delete() -- var.delete(0, tk.END):
# * Delete everything from character 0 to the END.
#
# # size () :
# * How many items are already in the Listbox?
#
# # var.curselection :
# * Suppose you click
#
# Study Python
#
# This returns
# (2,)
#
# Why 2?
# Because computers count like this:
#
# 0 → Clean Room
#
# 1 → Buy Milk
#
# 2 → Study Python
